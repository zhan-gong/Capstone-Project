# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('C:/Users/Zhan Gong/Capstone-Project/data.csv')

# %%
df1
# Out:
#           1st Ban enemy's 1st Ban           2nd Ban enemy's 2nd Ban  \
# 0              Io     Drow Ranger       Void Spirit          Magnus
# 1      Lone Druid          Magnus           Slardar     Drow Ranger
# 2   Faceless Void            Chen  Nature's Prophet      Lone Druid
# 3     Enchantress          Magnus              Lina              Io
# 4     Enchantress          Magnus   Vengeful Spirit              Io
# ..            ...             ...               ...             ...
# 95    Beastmaster           Lycan                Io      Lone Druid
# 96    Beastmaster   Queen of Pain                Io           Lycan
# 97  Queen of Pain           Lycan                Io          Rubick
# 98   Ember Spirit           Lycan     Dragon Knight      Lone Druid
# 99  Death Prophet        Batrider           Phoenix       Timbersaw
#
#                1st Pick  enemy's 1st Pick              2ndPick  \
# 0                  Lina            Oracle          Lifestealer
# ...

# %%
target = df1['Result']
df2 = df1.drop(columns = ['Result'])

# %%
target
# Out:
# 0     Lost
# 1     Lost
# 2      Won
# 3     Lost
# 4     Lost
#       ...
# 95     Won
# 96    Lost
# 97     Won
# 98     Won
# 99    Lost
# Name: Result, Length: 100, dtype: object

# %%
df2
# Out:
#           1st Ban enemy's 1st Ban           2nd Ban enemy's 2nd Ban  \
# 0              Io     Drow Ranger       Void Spirit          Magnus
# 1      Lone Druid          Magnus           Slardar     Drow Ranger
# 2   Faceless Void            Chen  Nature's Prophet      Lone Druid
# 3     Enchantress          Magnus              Lina              Io
# 4     Enchantress          Magnus   Vengeful Spirit              Io
# ..            ...             ...               ...             ...
# 95    Beastmaster           Lycan                Io      Lone Druid
# 96    Beastmaster   Queen of Pain                Io           Lycan
# 97  Queen of Pain           Lycan                Io          Rubick
# 98   Ember Spirit           Lycan     Dragon Knight      Lone Druid
# 99  Death Prophet        Batrider           Phoenix       Timbersaw
#
#                1st Pick  enemy's 1st Pick              2ndPick  \
# 0                  Lina            Oracle          Lifestealer
# ...

# %%
target_names = ['Won','Lost']

# %%
target = np.array(target)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df2,target, random_state = 0)

# %%
print("X_train shape: {}".format(X_train.shape))
print("y_train shape: {}".format(y_train.shape))
print("X_test shape: {}".format(X_test.shape))
print("y_test shape: {}".format(y_test.shape))
# Out:
# X_train shape: (75, 24)
# y_train shape: (75,)
# X_test shape: (25, 24)
# y_test shape: (25,)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
data = df2.loc[:,'1st Ban':'enemy\'s 1st Ban'].values
for train_index, test_index in split.split(data2, target):
    X_train = data[train_index]
    X_test = data[test_index]
    y_train = data[train_index]
    y_test = data[test_index]

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
