# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('C:/Users/Zhan Gong/Capstone-Project/data2.csv')

# %%
df1
# Out:
#     1st Ban  enemy's 1st Ban  2nd Ban  enemy's 2nd Ban  1st Pick  \
# 0         1                7       34                8        41
# 1         2                8       40                7         1
# 2         3               27       19                2         8
# 3         4                8       41                1        43
# 4         4                8       10                1        43
# ..      ...              ...      ...              ...       ...
# 95       22               17        1                2         4
# 96       22               18        1               17         4
# 97       18               17        1               29        52
# 98       16               17       35                2        39
# 99       26               13        5               46        23
#
#     enemy's 1st Pick  2ndPick  enemy's 2nd Pick  3rd Ban  enemy's 3rd Ban  \
# 0                 44       28                70       40               22
# 1                 34       66                38        3               89
# 2                 29       49                28       42               41
# 3                 10       55                 7       40               46
# 4                 41        3                40       69               29
# ..               ...      ...               ...      ...              ...
# 95                47       37                35       61               18
# 96                61       29                81       47                2
# 97                19       34                24       22                2
# 98                21       52                19       27               38
# 99                35       29                61       87               47
#
#     ...  enemy's 3rd Pick  4th Pick  enemy's 4th Pick  6th Ban  \
# 0   ...                46        66                83       29
# 1   ...                44        35                69      115
# 2   ...                78        82                22       90
# 3   ...                66        28                24       35
# 4   ...                27        49                28       83
# ..  ...               ...       ...               ...      ...
# 95  ...                63        13                67       45
# 96  ...                10        70                37       86
# 97  ...                27        39                94       45
# 98  ...                97        92                90       45
# 99  ...                63        71                18       79
#
#     enemy's 6th Ban  7th Ban  enemy's 7th Ban  5th Pick  enemy's 5th Pick  \
# 0                77       24              115        16                39
# 1                45       46               83        15               110
# 2                10       53               77         4                46
# 3                53       92               26        34                83
# 4               102       88               26        15                35
# ..              ...      ...              ...       ...               ...
# 95              114       -1               -1        30                31
# 96               13       -1               -1        34                45
# 97              110       -1               -1        20                92
# 98               13       -1               -1       106                91
# 99               96       -1               -1       117                67
#
#     Result
# 0     Lost
# 1     Lost
# 2      Won
# 3     Lost
# 4     Lost
# ..     ...
# 95     Won
# 96    Lost
# 97     Won
# 98     Won
# 99    Lost
#
# [100 rows x 25 columns]

# %%
target = df1['Result']
df2 = df1.drop(columns = ['Result'])
target_names = ['Won','Lost']
target = np.array(target)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df2,target, random_state = 0)
print("X_train shape: {}".format(X_train.shape))
print("y_train shape: {}".format(y_train.shape))
print("X_test shape: {}".format(X_test.shape))
print("y_test shape: {}".format(y_test.shape))
# Out:
# X_train shape: (75, 24)
# y_train shape: (75,)
# X_test shape: (25, 24)
# y_test shape: (25,)

# %%
#Current Code

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

# %%
df0 = pd.read_csv('data2.csv')
df = df0.drop(columns = ['Result'])
df
# Out:
#     1st Ban  enemy's 1st Ban  2nd Ban  enemy's 2nd Ban  1st Pick  \
# 0         1                7       34                8        41
# 1         2                8       40                7         1
# 2         3               27       19                2         8
# 3         4                8       41                1        43
# 4         4                8       10                1        43
# ..      ...              ...      ...              ...       ...
# 95       22               17        1                2         4
# 96       22               18        1               17         4
# 97       18               17        1               29        52
# 98       16               17       35                2        39
# 99       26               13        5               46        23
#
#     enemy's 1st Pick  2ndPick  enemy's 2nd Pick  3rd Ban  enemy's 3rd Ban  \
# 0                 44       28                70       40               22
# 1                 34       66                38        3               89
# 2                 29       49                28       42               41
# 3                 10       55                 7       40               46
# 4                 41        3                40       69               29
# ..               ...      ...               ...      ...              ...
# 95                47       37                35       61               18
# 96                61       29                81       47                2
# 97                19       34                24       22                2
# 98                21       52                19       27               38
# 99                35       29                61       87               47
#
#     ...  3rd Pick  enemy's 3rd Pick  4th Pick  enemy's 4th Pick  6th Ban  \
# 0   ...        42                46        66                83       29
# 1   ...        29                44        35                69      115
# 2   ...       102                78        82                22       90
# 3   ...       103                66        28                24       35
# 4   ...        84                27        49                28       83
# ..  ...       ...               ...       ...               ...      ...
# 95  ...        39                63        13                67       45
# 96  ...        59                10        70                37       86
# 97  ...       100                27        39                94       45
# 98  ...       100                97        92                90       45
# 99  ...        99                63        71                18       79
#
#     enemy's 6th Ban  7th Ban  enemy's 7th Ban  5th Pick  enemy's 5th Pick
# 0                77       24              115        16                39
# 1                45       46               83        15               110
# 2                10       53               77         4                46
# 3                53       92               26        34                83
# 4               102       88               26        15                35
# ..              ...      ...              ...       ...               ...
# 95              114       -1               -1        30                31
# 96               13       -1               -1        34                45
# 97              110       -1               -1        20                92
# 98               13       -1               -1       106                91
# 99               96       -1               -1       117                67
#
# [100 rows x 24 columns]

# %%
target1 = pd.get_dummies(df0['Result'])
target1 = target1.drop(columns = ['Lost'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df, target1, random_state = 0)
print("X_train shape: {}".format(X_train.shape))
print("y_train shape: {}".format(Y_train.shape))
print("X_test shape: {}".format(X_test.shape))
print("y_test shape: {}".format(Y_test.shape))
# Out:
# X_train shape: (75, 24)
# y_train shape: (75, 1)
# X_test shape: (25, 24)
# y_test shape: (25, 1)

# %%
#Creat Train Tensor

# %%
x_train = np.mat(X_train.fillna(value=-1))
x_train = torch.tensor(x_train).float()
y_train = np.mat(Y_train.fillna(value=-1))
y_train = torch.tensor(y_train).float()

# %%
#Creat Test Tensor

# %%
x_test = np.mat(X_test.fillna(value=-1))
x_test = torch.tensor(x_test).float()
y_test = np.mat(Y_test.fillna(value=-1))
y_test = torch.tensor(y_test).float()

# %%
#Define Neturl Network

# %%
class myNet(nn.Module):
  
  def __init__(self):
    ''' 
      Initialization of my Neural Network
    '''

    super(myNet, self).__init__()
    
    self.layer1 = nn.Linear(24, 16)
    self.layer2 = nn.Linear(16, 8)
    self.layer3 = nn.Linear(8, 1)
    self.output = nn.Sigmoid()

  def forward(self, x):
    '''
      Forward-Propagation
    '''
    x = nn.functional.relu(self.layer1(x))
    x = nn.functional.relu(self.layer2(x))
    x = self.layer3(x)
      
    return self.output(x)

# %%
#Setup Neural Network with Optimizer and Loss Function

# %%
model = myNet()
optimzer = torch.optim.SGD(model.parameters(), lr = 0.001, momentum = 0.9)
loss_func = nn.MSELoss()

# %%
#Display Neural Network Architecture

# %%
print(model)
# Out:
# myNet(
#   (layer1): Linear(in_features=24, out_features=16, bias=True)
#   (layer2): Linear(in_features=16, out_features=8, bias=True)
#   (layer3): Linear(in_features=8, out_features=1, bias=True)
#   (output): Sigmoid()
# )

# %%
#Train Neural Network

# %%
for epoch in range(500):
  for i in range(0, len(x_train)):
    if not(torch.any(x_train[i].isnan())):
      optimzer.zero_grad() 
      out = model(x_train[i])
      loss = loss_func(out, y_train[i])
      
      loss.backward()
      optimzer.step()

      if i % 50 is 0:
        print("Network Output: ", out)
        print("Actual Label: ", y_train[i])
        print("Current Loss: ", loss.item())
# Out:
# Network Output:  tensor([0.0005], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  2.4440723223051464e-07
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  2.2737367544323206e-09
# Network Output:  tensor([0.0005], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  2.4038786250457633e-07
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  2.2172486069393926e-09
# Network Output:  tensor([0.0005], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  2.3649664626645972e-07
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  2
-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# ...
# Actual Label:  tensor([1.])
# Current Loss:  8.208189683500677e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.277094234339529e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  8.208189683500677e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.276637355360435e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  8.208189683500677e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.27053308271752e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  8.208189683500677e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.269230302611504e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.993605777301127e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.262966157853043e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.993605777301127e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.2584808568335575e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.993605777301127e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.2438319525217594e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.993605777301127e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.2375731368338165e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.993605777301127e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.23749213496194e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.993605777301127e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.223503680123031e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.993605777301127e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.221892524469695e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.993605777301127e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.216116167299333e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.781864042044617e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.202918901796693e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.781864042044617e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.2013326151391084e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.781864042044617e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.2002511690952815e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.781864042044617e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.194672342805461e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.781864042044617e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.1815823692559206e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.781864042044617e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.1799719241453204e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.781864042044617e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.1794056215849196e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.781864042044617e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.161535827051921e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.781864042044617e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.1601150968517686e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.572964477731148e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.159409172643791e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.572964477731148e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.145780962971912e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.572964477731148e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.1398479311283154e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.572964477731148e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.1396429395490486e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.572964477731148e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.135303655061762e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.572964477731148e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.120009933217261e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.572964477731148e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.113995899501788e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.572964477731148e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.1138779494076516e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.366907084360719e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.1128739525220226e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.366907084360719e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.108663986812644e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.366907084360719e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.0893809227782185e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.366907084360719e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.0886320107347274e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.366907084360719e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.0876336981909844e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.366907084360719e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.073409343163803e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.366907084360719e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.067959835651891e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.366907084360719e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.067153369646803e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.366907084360719e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.066502157229479e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.16369186193333e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.0624019703727754e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.16369186193333e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.0522429856082454e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.16369186193333e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.040044387920716e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.16369186193333e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.0387039490497045e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.16369186193333e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.0377564403115684e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.16369186193333e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.020898458634292e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.16369186193333e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.0203232742896944e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.16369186193333e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.0193960160195275e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.16369186193333e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.0184453098390804e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  7.16369186193333e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  4.008710163816431e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.963318810448982e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.9968561793557456e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.963318810448982e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.995575426074538e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.963318810448982e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.994684405483895e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.963318810448982e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.978279039529298e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.963318810448982e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.977649853936782e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.963318810448982e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.976761675517082e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.963318810448982e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.965153894114337e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.963318810448982e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.9601204093742126e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.963318810448982e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.959259586849839e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.765787929907674e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.958738403753159e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.765787929907674e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.9533528450874655e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.765787929907674e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.936794001901944e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.765787929907674e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.9358102554842844e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.765787929907674e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.935728187798304e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.765787929907674e-11
# Network Output:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([0.])
# Current Loss:  3.932052194954849e-08
# Network Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])
# Current Loss:  6.765787929907674e-11

# %%
print("Output: ", model(x_test[3]))
print("Actual: ", y_test[3])
# Out:
# Output:  tensor([0.9997], grad_fn=<SigmoidBackward>)
# Actual:  tensor([1.])

# %%
#Test the network

# %%
model.eval()

avg_cost = 0.0

for i in range(1, len(x_test)):
  out = model(x_test[i])
  loss = loss_func(out, y_test[i])

  avg_cost += loss.item()

print('Test Average Loss: %f' % (float(avg_cost) / float(len(x_test))))
# Out:
# Test Average Loss: 0.131873

# %%
#Data Genarate

# %%
print("Output: ", model(x_train[50]))
print("Actual Label: ", y_train[i])
# Out:
# Output:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# Actual Label:  tensor([1.])

# %%
series = np.mat(series.fillna(value=-1))
series = torch.tensor(series).float()

# %%
data
# Out:
# [15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15]

# %%
series = pd.Series(x)

# %%
df.columns.values
# Out:
# array(['1st Ban', "enemy's 1st Ban", '2nd Ban', "enemy's 2nd Ban",
#        '1st Pick', "enemy's 1st Pick", '2ndPick', "enemy's 2nd Pick",
#        '3rd Ban', "enemy's 3rd Ban", '4th Ban', "enemy's 4th Ban",
#        '5th Ban', "enemy's 5th Ban", '3rd Pick', "enemy's 3rd Pick",
#        '4th Pick', "enemy's 4th Pick", '6th Ban', "enemy's 6th Ban",
#        '7th Ban', "enemy's 7th Ban", '5th Pick', "enemy's 5th Pick"],
#       dtype=object)

# %%
x=np.random.randint(1,110,size = 24)

# %%
series = pd.Series(x)

# %%
series = np.mat(series.fillna(value=-1))
series = torch.tensor(series).float()

# %%
print("Output: ", model(series))
# Out:
# Output:  tensor([[0.5113]], grad_fn=<SigmoidBackward>)

# %%
x
# Out:
# array([ 85,  64,  10,  63,  74,  67,  33,  54,  27,  94,  49,  30,   6,
#        104,   4,  59,  96,   7,  88,  86,  64,   4,  96,  63])

# %%
50%50
# Out:
# 0
